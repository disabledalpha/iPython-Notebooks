# %%
# %matplotlib inline
import numpy as np
import scipy
import pylab
from scipy import ndimage
from scipy import misc
import matplotlib.pyplot as plt

# %%
l = misc.lena()
plt.imshow(l, cmap=plt.cm.gray)
plt.show()

# %%
fl = np.fft.fft2(l)
plt.imshow(np.abs(fl))
plt.show()

# %%
np.size(fl)-np.count_nonzero(fl)
# Out:
# 0

# %%
fl
# Out:
# array([[  3.25181200e+07      +0.j        ,
#          -4.55357065e+05+2392745.81180872j,
#           1.53597138e+06-1135509.41538587j, ...,
#          -2.36883748e+05 -635286.44808319j,
#           1.53597138e+06+1135509.41538586j,
#          -4.55357065e+05-2392745.81180872j],
#        [ -3.03205988e+04-1224303.2052211j ,
#          -1.58729983e+06+1593728.44153545j,
#          -1.10627267e+06  +78465.22223467j, ...,
#           6.51498912e+05 +813470.27041887j,
#          -3.55411923e+05 +447275.6220858j ,
#           3.54810673e+04 +946078.76670701j],
#        [ -4.49721550e+05 -163333.81820253j,
#          -2.75144660e+05 -133147.84700228j,
#           6.67298685e+05 -455726.33659109j, ...,
#           3.52621851e+05 +927063.46717784j,
#          -7.23394350e+05 -175837.39340613j,
#           8.21395141e+05  -64041.00626408j],
#        ...,
#        [  5.16397897e+05 -214951.70930405j,
#           7.35344981e+05 +708410.03287204j,
# ...

# %%
fl[256,:]
# Out:
# array([  4.12200000e+03 +0.00000000e+00j,
#          2.94443694e+03 -2.10305529e+03j,
#          3.21722202e+02 +3.58623071e+03j,
#         -1.67648886e+03 -1.20300626e+03j,
#          2.34470747e+03 +8.18523257e+02j,
#          1.91148726e+03 +7.04723321e+02j,
#          1.18399466e+03 +1.63298465e+03j,
#          6.70901417e+02 -3.37630932e+02j,
#          1.88369053e+03 -1.98106574e+03j,
#         -1.41069077e+02 -1.08986651e+03j,
#          6.62259858e+02 +2.24174844e+03j,
#          2.48066461e+02 -7.97313705e+02j,
#         -1.67470482e+03 +6.20969625e+02j,
#          1.83329151e+03 +9.51230468e+02j,
#          8.50046566e+02 -1.42862006e+03j,
#          3.96703087e+02 +1.09961495e+03j,
#          1.37545645e+03 +8.60818448e+02j,
#         -1.69133327e+03 -1.35550165e+02j,
#         -9.62809663e+01 -9.48264180e+02j,
#          2.96687282e+02 -2.77168432e+03j,
#          1.79888526e+02 -1.12313869e+03j,
#         -2.39498720e+02 +3.16719888e+03j,
# ...
